# %% [markdown]
# <a href="https://colab.research.google.com/github/nollamae7-spec/DSRSP-Solar-Flares/blob/Storage-for-old-code/storage_document_Solar_Flares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Frame Opening

# %%
# !pip install pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/frontiertechinstitute/datasets/raw/main/Solar%20Flares%20Dataset/solar_flares.csv'
df = pd.read_csv(url)

df.head(10)
# Out:
#   zurich_class largest_spot_size spot_distribution  activity  evolution  \
# 0            C                 S                 O         1          2
# 1            D                 S                 O         1          3
# 2            C                 S                 O         1          3
# 3            D                 S                 O         1          3
# 4            D                 A                 O         1          3
# 5            D                 A                 O         1          2
# 6            D                 A                 O         1          2
# 7            D                 A                 O         1          2
# 8            D                 K                 O         1          3
# 9            C                 R                 O         1          3
#
#    prev_24hr_flare_activity  historically_complex  became_complex_this_pass  \
# 0                         1                     1                         2
# ...

# %% [markdown]
# # Learning about the Data Frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zurich_class              1389 non-null   object
#  1   largest_spot_size         1389 non-null   object
#  2   spot_distribution         1389 non-null   object
#  3   activity                  1389 non-null   int64
#  4   evolution                 1389 non-null   int64
#  5   prev_24hr_flare_activity  1389 non-null   int64
#  6   historically_complex      1389 non-null   int64
#  7   became_complex_this_pass  1389 non-null   int64
#  8   area                      1389 non-null   int64
#  9   area_largest_spot         1389 non-null   int64
#  10  c_class_flares            1389 non-null   int64
#  11  m_class_flares            1389 non-null   int64
#  12  x_class_flares            1389 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 141.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zurich_class              1389 non-null   object
#  1   largest_spot_size         1389 non-null   object
#  2   spot_distribution         1389 non-null   object
#  3   activity                  1389 non-null   int64
#  4   evolution                 1389 non-null   int64
#  5   prev_24hr_flare_activity  1389 non-null   int64
#  6   historically_complex      1389 non-null   int64
#  7   became_complex_this_pass  1389 non-null   int64
#  8   area                      1389 non-null   int64
#  9   area_largest_spot         1389 non-null   int64
#  10  c_class_flares            1389 non-null   int64
#  11  m_class_flares            1389 non-null   int64
#  12  x_class_flares            1389 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 141.2+ KB

# %%
df["m_class_flares"].unique()
# Out:
# array([0, 1, 2, 4, 3, 5])

# %%
df[df["m_class_flares"]==1]
# Out:
#      zurich_class largest_spot_size spot_distribution  activity  evolution  \
# 45              D                 A                 I         1          3
# 53              D                 K                 C         2          3
# 76              D                 S                 I         1          2
# 91              D                 K                 I         1          3
# 107             D                 K                 C         1          3
# 111             C                 S                 I         2          3
# 112             C                 S                 O         1          1
# 153             C                 S                 O         1          3
# 165             C                 S                 O         2          2
# 198             C                 S                 O         1          3
# 200             B                 X                 O         1          3
# ...

# %%
df['zurich_class'].unique()
# Out:
# array(['C', 'D', 'B', 'F', 'H', 'E'], dtype=object)

# %% [markdown]
# # Duplicates

# %% [markdown]
# I think there are repeated observations of the same sunspots. This may be the reason there are so many duplicates... something to explore later.

# %%
dfDupOnly = df[df['m_class_flares']==1].duplicated()

# %%
duplicated_rows = df[df.duplicated()]
print(duplicated_rows)
# Out:
#      zurich_class largest_spot_size spot_distribution  activity  evolution  \
# 3               D                 S                 O         1          3
# 7               D                 A                 O         1          2
# 15              B                 X                 O         1          3
# 21              B                 X                 O         1          3
# 23              B                 X                 O         1          2
# ...           ...               ...               ...       ...        ...
# 1384            H                 S                 X         1          2
# 1385            H                 S                 X         2          2
# 1386            C                 S                 O         1          2
# 1387            H                 R                 X         1          2
# 1388            B                 X                 O         1          1
#
#       prev_24hr_flare_activity  historically_complex  \
# ...

# %%
df[df['m_class_flares']==1].duplicated()
# Out:
# 45      False
# 53      False
# 76      False
# 91      False
# 107     False
# 111     False
# 112     False
# 153     False
# 165     False
# 198     False
# 200     False
# 213     False
# 217     False
# 218     False
# 223     False
# 241     False
# 254     False
# 257     False
# 259     False
# 264     False
# 265     False
# 285     False
# 299     False
# 301     False
# 360     False
# 380     False
# 486     False
# 494     False
# 533     False
# 557     False
# 628     False
# 647     False
# 679     False
# 691     False
# 696     False
# 699     False
# 764     False
# 776     False
# 804     False
# 818     False
# 824     False
# 912     False
# 1023    False
# 1024    False
# 1142     True
# 1153     True
# 1162    False
# 1240    False
# 1273    False
# 1332    False
# 1341    False
# 1345    False
# 1369    False
# dtype: bool

# %% [markdown]
# # Beginning Visualizations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zurich_class              1389 non-null   object
#  1   largest_spot_size         1389 non-null   object
#  2   spot_distribution         1389 non-null   object
#  3   activity                  1389 non-null   int64
#  4   evolution                 1389 non-null   int64
#  5   prev_24hr_flare_activity  1389 non-null   int64
#  6   historically_complex      1389 non-null   int64
#  7   became_complex_this_pass  1389 non-null   int64
#  8   area                      1389 non-null   int64
#  9   area_largest_spot         1389 non-null   int64
#  10  c_class_flares            1389 non-null   int64
#  11  m_class_flares            1389 non-null   int64
#  12  x_class_flares            1389 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 141.2+ KB

# %%
df.value_counts()
# Out:
# zurich_class  largest_spot_size  spot_distribution  activity  evolution  prev_24hr_flare_activity  historically_complex  became_complex_this_pass  area  area_largest_spot  c_class_flares  m_class_flares  x_class_flares
# B             X                  O                  1         3          1                         1                     2                         1     1                  0               0               0                 90
# H             S                  X                  1         2          1                         1                     2                         1     1                  0               0               0                 44
# C             R                  O                  1         3          1                         1                     2                         1     1                  0               0               0                 43
# ...

# %%
#This cannot be a scatter, it's the wrong variable types.... I'm leaving the code to see it tho
zurichClassVsArea = pd.DataFrame({'x':df["zurich_class"], 'y':df["area"]})

plt.scatter(zurichClassVsArea['x'], zurichClassVsArea['y'])

plt.xlabel("Zurich Class")
plt.ylabel("Area")
plt.show()

# %%
#categorical and numerical... needs to be a bar graph

zc_v_area_counts = df.groupby("zurich_class")["area"].count()
plt.bar(zc_v_area_counts.index, zc_v_area_counts.values)

plt.xlabel("Zurich Class")
plt.ylabel("Area")
plt.show()

# %%
zurichClassVsCClassFlares = pd.DataFrame({'x':df["zurich_class"], 'y':df["c_class_flares"]})

c_class_counts = zurichClassVsCClassFlares["y"].value_counts()

plt.bar(c_class_counts.index, c_class_counts.values)
plt.xlabel("Zurich Class")
plt.ylabel("C Class Flares")
plt.show()

# %%
#Z Class v C class flares scatter...
zurichClassVsCClassFlares = pd.DataFrame({'x':df["zurich_class"], 'y':df["c_class_flares"]})

plt.scatter(zurichClassVsCClassFlares['x'], zurichClassVsCClassFlares['y'])
plt.xlabel("Zurich Class")
plt.ylabel("C Class Flares")
plt.show()

# %%
zurichClassVsLargestSpotSize = pd.DataFrame({'x':df["zurich_class"], 'y':df["largest_spot_size"]})

plt.scatter(zurichClassVsLargestSpotSize['x'], zurichClassVsLargestSpotSize['y'])
plt.xlabel("Zurich Class")
plt.ylabel("Largest Spot Size")
plt.show()

# %%
ActivityVsEvolution = pd.DataFrame({'x':df["activity"], 'y':df["evolution"]})

plt.scatter(ActivityVsEvolution['x'], ActivityVsEvolution['y'])
plt.xlabel("Activity")
plt.ylabel("Evolution")
plt.show()

# %%
zurichClassVsSpotDistribution = pd.DataFrame({'x':df["zurich_class"], 'y':df["spot_distribution"]})

plt.scatter(zurichClassVsSpotDistribution['x'], zurichClassVsSpotDistribution['y'])
plt.xlabel("Zurich Class")
plt.ylabel("Spot Distributions")
plt.show()

# %% [markdown]
# # ZPC Class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zurich_class              1389 non-null   object
#  1   largest_spot_size         1389 non-null   object
#  2   spot_distribution         1389 non-null   object
#  3   activity                  1389 non-null   int64
#  4   evolution                 1389 non-null   int64
#  5   prev_24hr_flare_activity  1389 non-null   int64
#  6   historically_complex      1389 non-null   int64
#  7   became_complex_this_pass  1389 non-null   int64
#  8   area                      1389 non-null   int64
#  9   area_largest_spot         1389 non-null   int64
#  10  c_class_flares            1389 non-null   int64
#  11  m_class_flares            1389 non-null   int64
#  12  x_class_flares            1389 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 141.2+ KB

# %%
df['zurich_class'].unique()
# Out:
# array(['C', 'D', 'B', 'F', 'H', 'E'], dtype=object)

# %%
df['largest_spot_size'].unique()
# Out:
# array(['S', 'A', 'K', 'R', 'X', 'H'], dtype=object)

# %%
df['spot_distribution'].unique()
# Out:
# array(['O', 'I', 'X', 'C'], dtype=object)

# %%
#This tells you the number of each Sunspot class... bc it's ZPC, and those are broken up in the dataset
(((df['zurich_class']== 'B') & (df['largest_spot_size']== 'R') & (df['spot_distribution']== 'C'))== True).sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Analysis of 24 hr activity vs total_flares

# %%
plt.scatter(df["prev_24hr_flare_activity"], df["total_flares"])
plt.title("previous 24 hour activity vs total flares")
plt.ylabel("total flares")
plt.xlabel("previous 24 hour activity (1= <M1, 2= M1, 3 = >M1)")
plt.xticks([1,2,3])



plt.show()

# %%
df["prev_24hr_flare_activity"].unique()
# Out:
# array([1, 3, 2])

# %%
df_flares1 = df[df["prev_24hr_flare_activity"] == 1]

# %%
total_1 = df_flares1["total_flares"].sum()

# %%
df_flares2 = df[df['prev_24hr_flare_activity']== 2]

# %%
total_2 = df_flares2['total_flares'].sum()

# %%
df_flares3 = df[df['prev_24hr_flare_activity']== 3]

# %%
total_3 = df_flares3['total_flares'].sum()

# %%
x_class_counts = df['x_class_flares'].value_counts()
plt.bar(x_class_counts.index, x_class_counts.values)
plt.title("Number of datapoints for x class flares")
plt.xlabel("Number of X Class Flares")
plt.ylabel("Number of entries")
plt.show()

# %%
m_class_counts = df['m_class_flares'].value_counts()
plt.bar(m_class_counts.index, m_class_counts.values)
plt.title("Number of datapoints for M class flares")
plt.xlabel("Number of M Class Flares")
plt.ylabel("Number of entries")
plt.show()

# %% [markdown]
# # Histograms

# %%
plt.hist(df["zurich_class"],
         bins = 6)
plt.show()

# %%
x_class_numbers = df["x_class_flares"].value_counts()
plt.bar(x_class_numbers.index, x_class_numbers.values)
plt.show()

# %%
(df["m_class_flares"]>0).sum()
# Out:
# np.int64(68)

# %% [markdown]
# # Learning about the Data Frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zurich_class              1389 non-null   object
#  1   largest_spot_size         1389 non-null   object
#  2   spot_distribution         1389 non-null   object
#  3   activity                  1389 non-null   int64
#  4   evolution                 1389 non-null   int64
#  5   prev_24hr_flare_activity  1389 non-null   int64
#  6   historically_complex      1389 non-null   int64
#  7   became_complex_this_pass  1389 non-null   int64
#  8   area                      1389 non-null   int64
#  9   area_largest_spot         1389 non-null   int64
#  10  c_class_flares            1389 non-null   int64
#  11  m_class_flares            1389 non-null   int64
#  12  x_class_flares            1389 non-null   int64
#  13  total_flares              1389 non-null   int64
# ...

# %%
df["m_class_flares"].unique()
# Out:
# array([0, 1, 2, 4, 3, 5])

# %%
df['x_class_flares'].value_counts()
# Out:
# x_class_flares
# 0    1377
# 1      11
# 2       1
# Name: count, dtype: int64

# %%
df['zurich_class'].unique()
# Out:
# array(['C', 'D', 'B', 'F', 'H', 'E'], dtype=object)

# %% [markdown]
# # Exploring individual class flares

# %%
df[df["x_class_flares"]>0]
# Out:
#      zurich_class largest_spot_size spot_distribution  activity  evolution  \
# 30              D                 A                 O         1          3
# 62              D                 K                 C         2          3
# 75              D                 K                 I         1          3
# 106             H                 S                 X         1          1
# 257             D                 K                 C         1          3
# 259             H                 A                 X         1          3
# 310             D                 K                 C         2          2
# 546             F                 A                 I         2          2
# 1273            F                 K                 C         1          2
# 1283            D                 K                 C         2          3
# 1292            E                 K                 C         2          3
# ...

# %%
df["x_class_flares"].value_counts()
# Out:
# x_class_flares
# 0    1377
# 1      11
# 2       1
# Name: count, dtype: int64

# %%
df["m_class_flares"].value_counts()
# Out:
# m_class_flares
# 0    1321
# 1      53
# 2       9
# 4       3
# 3       2
# 5       1
# Name: count, dtype: int64

# %%
df["c_class_flares"].value_counts()
# Out:
# c_class_flares
# 0    1171
# 1     141
# 2      40
# 3      20
# 4       9
# 5       4
# 6       3
# 8       1
# Name: count, dtype: int64

# %% [markdown]
# # Different Variable Comparisons

# %% [markdown]
# John said to make a research question along the lines of 'which variable affects the flares the most'

# %%
plt.scatter(df["area"], df["c_class_flares"])
plt.title("Area vs C Class Flares")
plt.xlabel("Area")
plt.ylabel("C class flares")
plt.xticks([1,2])

plt.show()

# %% [markdown]
# X class vs evolution.
#
# Evolution   (1 = decay, 2 = no growth, 3 = growth)
#
# Previous 24 hour flare activity code    (1 = nothing as big as an M1, 2 = one M1, 3 = more activity than one M1)
#
# the only time there were 2 x-class flares were when the sunspot had growth.

# %%
plt.scatter (df["x_class_flares"], df["evolution"])

plt.title("evolution vs x class flares")
plt.xlabel("X class Flares")
plt.ylabel("Evolution (1=decay, 2=no growth, 3=growth)")
plt.xticks([0,1,2])
plt.yticks([1,2,3])

plt.show()

# %%
plt.scatter (df["m_class_flares"], df["evolution"])

plt.title("evolution vs m class flares")
plt.xlabel("# of m class Flares")
plt.ylabel("Evolution")
plt.yticks([1,2,3])

plt.show()

# %%
plt.scatter (df["c_class_flares"], df["evolution"])

plt.title("evolution vs c class flares")
plt.xlabel("# of c class Flares")
plt.ylabel("Evolution")
plt.yticks([1,2,3])

plt.show()

# %% [markdown]
# x class flares vs area of the largest spot
#
# Area of the largest spot                (1 = <=5, 2 = >5)
#
# when the area of the largest spot was less than or equal to 5, there were 2 x class flares.

# %%
plt.scatter(df["x_class_flares"], df["area_largest_spot"])
plt.title("X class flares vs area of the largest spot in the sunspot grouping")
plt.xlabel("# of x class flares")
plt.ylabel("area of the largest spot")
plt.yticks([1,2])
plt.xticks([0,1,2])

plt.show()

# %% [markdown]
# # Complexity

# %%
#going to try to make a heat map
#plt.imshow(data=df["c_class_flares"], cmap="viridis")
#plt.show()
# That wasn't working so now trying to make the points bigger the more they have
#sns.scatterplot(data=df['historically_complex'], x=None, y=None, hue=None, size=None, style=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend='auto', ax=None)

# %% [markdown]
# #Historic complexity

# %%
#there are 2 instances where there are 8 total flares, this graph is accurate
plt.scatter(df["historically_complex"], df['total_flares'])
plt.title("total flares vs historic complexity")
plt.xticks([1,2])
plt.ylabel("total flares")
plt.xlabel("historic complexity (1=Yes, 2=No)")
plt.show()

# %%
plt.scatter(df["historically_complex"], df["m_class_flares"])
plt.title("m class flares vs historic complexity")
plt.ylabel("m_class_flares")
plt.xlabel("historic complexity (1=Yes, 2=No)")
plt.xticks([1,2])

plt.show()

# %%
plt.scatter(df["historically_complex"], df["x_class_flares"])
plt.title("x class flares vs historic complexity")
plt.ylabel("x_class_flares")
plt.xlabel("historic complexity (1=Yes, 2=No)")
plt.xticks([1,2])

plt.show()

# %% [markdown]
# # Became complex this pass

# %%
plt.scatter(df["became_complex_this_pass"], df["c_class_flares"])
plt.title("c class flares vs becoming complex this pass")
plt.ylabel("c_class_flares")
plt.xlabel("became complex this pass(1=yes, 2=no)")
plt.xticks([1,2])

plt.show()

# %%
plt.scatter(df["became_complex_this_pass"], df["m_class_flares"])
plt.title("m class flares vs becoming complex this pass")
plt.ylabel("m_class_flares")
plt.xlabel("became complex this pass(1=yes, 2=no)")
plt.xticks([1,2])


plt.show()

# %%
plt.scatter(df["became_complex_this_pass"], df["x_class_flares"])
plt.title("x class flares vs becoming complex this pass")
plt.ylabel("x_class_flares")
plt.xlabel("became complex this pass(1=yes, 2=no)")
plt.xticks([1,2])
plt.yticks([0,1,2])

plt.show()

# %% [markdown]
# new research question?
# # Is there a correlation between the complexity of a sunspot group and the number of flares?

# %% [markdown]
# # Total Flares compared to all variables

# %%
plt.scatter(df["area"], df["total_flares"])
plt.title("area vs total flares")
plt.ylabel("total flares")
plt.xlabel("area")
plt.xticks([1,2])

plt.show()

# %%
plt.scatter(df["prev_24hr_flare_activity"], df["total_flares"])
plt.title("previous 24 hour activity vs total flares")
plt.ylabel("total flares")
plt.xlabel("previous 24 hour activity (1= <M1, 2= M1, 3 = >M1)")
plt.xticks([1,2,3])


plt.show()

# %%
plt.scatter(df["evolution"], df["total_flares"])
plt.title("evolution vs total flares")
plt.ylabel("total flares")
plt.xlabel("evolution (1=decay, 2=no growth, 3=growth)")
plt.xticks([1,2,3])

plt.show()

# %%
plt.scatter(df["activity"], df["total_flares"])
plt.title("activity vs total flares")
plt.ylabel("total_flares")
plt.xlabel("activity (1=reduced, 2=unchanged)")
plt.xticks([1,2])
plt.show()

# %%
plt.scatter(df["area_largest_spot"], df["total_flares"])
plt.title("area of the largest spot vs total flares")
plt.ylabel("total flares")
plt.xlabel("area of largest spot (1= <=5, 2= >5)")
plt.xticks([1,2])


plt.show()

# %% [markdown]
# # Are flares with historic activity more likely to produce solar flares in the future

# %% [markdown]
# # Z Class totals

# %%
z_class_counts = df['zurich_class'].value_counts()
plt.bar(z_class_counts.index, z_class_counts.values)
plt.title("# of entries of Z class")
plt.xlabel("Zurich class")
plt.ylabel("Number of entries")
plt.show()

# %%
(df["zurich_class"]== 'B').sum()
# Out:
# np.int64(212)

# %%
(df["zurich_class"]== 'C').sum()
# Out:
# np.int64(287)

# %%
(df["zurich_class"]== 'D').sum()
# Out:
# np.int64(327)

# %%
(df["zurich_class"]== 'E').sum()
# Out:
# np.int64(116)

# %%
(df["zurich_class"]== 'F').sum()
# Out:
# np.int64(51)

# %%
(df["zurich_class"]== 'H').sum()
# Out:
# np.int64(396)
